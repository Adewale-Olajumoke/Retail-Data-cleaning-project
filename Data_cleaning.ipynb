# %%
import pandas as pd

# %%
#importing dataset
Data_cleaning=pd.read_csv("online_retail_dataset.csv")

# %%
Data_cleaning
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
#Visualising the first 20 of the dataset
Data_cleaning.head(20)
# Out:
#     InvoiceNo StockCode     Description  Quantity       InvoiceDate  \
# 0      221958  SKU_1964       White Mug        38  2020-01-01 00:00
# 1      771155  SKU_1241       White Mug        18  2020-01-01 01:00
# 2      231932  SKU_1501      Headphones        49  2020-01-01 02:00
# 3      465838  SKU_1760       Desk Lamp        14  2020-01-01 03:00
# 4      359178  SKU_1386       USB Cable       -30  2020-01-01 04:00
# 5      744167  SKU_1006    Office Chair        47  2020-01-01 05:00
# 6      210268  SKU_1087       USB Cable        25  2020-01-01 06:00
# 7      832180  SKU_1597        Notebook         8  2020-01-01 07:00
# 8      154886  SKU_1907  Wireless Mouse        19  2020-01-01 08:00
# 9      237337  SKU_1866      Headphones        40  2020-01-01 09:00
# 10     621430  SKU_1144        Notebook        49  2020-01-01 10:00
# 11     187498  SKU_1450    Office Chair        41  2020-01-01 11:00
# 12     999159  SKU_1330        Blue Pen        41  2020-01-01 12:00
# ...

# %%
#Visualizing the last 20 from the tail
Data_cleaning.tail(20)
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 49762     691338  SKU_1543    Wall Clock        19  2025-09-04 10:00
# 49763     115451  SKU_1660  Office Chair        21  2025-09-04 11:00
# 49764     465384  SKU_1165      Blue Pen        28  2025-09-04 12:00
# 49765     414230  SKU_1409    Wall Clock        18  2025-09-04 13:00
# 49766     148393  SKU_1296     USB Cable        10  2025-09-04 14:00
# 49767     748751  SKU_1688     Desk Lamp        43  2025-09-04 15:00
# 49768     575634  SKU_1852      Blue Pen        37  2025-09-04 16:00
# 49769     701257  SKU_1092  Office Chair        19  2025-09-04 17:00
# 49770     625657  SKU_1628  Office Chair       -30  2025-09-04 18:00
# 49771     376212  SKU_1936      Notebook         1  2025-09-04 19:00
# 49772     224131  SKU_1095     USB Cable        27  2025-09-04 20:00
# 49773     370260  SKU_1570      Blue Pen        12  2025-09-04 21:00
# 49774     274759  SKU_1899     USB Cable        43  2025-09-04 22:00
# ...

# %%
Data_cleaning.info

# %%
#getting the column in the dataset
Data_cleaning.columns

# %%
#logical operation:and,or, not
Data_cleaning[(Data_cleaning['ShippingCost']>13)& (Data_cleaning['Country']=='United Kingdom')]
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 32        358795  SKU_1023    Headphones        30  2020-01-02 08:00
# 55        356840  SKU_1747  Office Chair        36  2020-01-03 07:00
# 76        704365  SKU_1528  Office Chair        14  2020-01-04 04:00
# 84        441097  SKU_1161       T-shirt         7  2020-01-04 12:00
# 106       633556  SKU_1948     USB Cable        34  2020-01-05 10:00
# ...          ...       ...           ...       ...               ...
# 49670     717340  SKU_1413    Headphones        10  2025-08-31 14:00
# 49676     459149  SKU_1568       T-shirt        34  2025-08-31 20:00
# 49762     691338  SKU_1543    Wall Clock        19  2025-09-04 10:00
# 49776     524453  SKU_1316  Office Chair        43  2025-09-05 00:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
#getting a particular name or person
Data_Name=Data_cleaning[Data_cleaning['InvoiceNo'].Str.contain("Apparel",cases= false)
# Out:
#   Cell In[9], line 2
#     Data_Name=Data_cleaning[Data_cleaning['InvoiceNo'].Str.contain("Apparel",cases= false)
#                                                                                           ^
# SyntaxError: incomplete input

# %%
Data_cleaning.dtypes

# %%
#sorting of value ascending using true or false
Sort_data= Data_cleaning.sort_values('Category', ascending = False).head(20)
Sort_data

# %%
#slicing using iloc
Sort_data[0:10]
# Out:
#        InvoiceNo StockCode     Description  Quantity       InvoiceDate  \
# 49781     772215  SKU_1832       White Mug        30  2025-09-05 05:00
# 13068     823380  SKU_1426    Office Chair        40  2021-06-28 12:00
# 36901     784208  SKU_1643  Wireless Mouse        12  2024-03-17 13:00
# 13047     565944  SKU_1850        Notebook        19  2021-06-27 15:00
# 36892     124272  SKU_1600       White Mug         1  2024-03-17 04:00
# 13051     161394  SKU_1431      Wall Clock         8  2021-06-27 19:00
# 36886     813037  SKU_1352      Wall Clock        32  2024-03-16 22:00
# 36881     929431  SKU_1198       USB Cable        15  2024-03-16 17:00
# 13058     342556  SKU_1073      Headphones        -4  2021-06-28 02:00
# 13061     466590  SKU_1881       White Mug        17  2021-06-28 05:00
#
#        UnitPrice  CustomerID      Country  Discount  PaymentMethod  \
# 49781      38.27     53328.0       France      0.10    Credit Card
# ...

# %%
#data cleaning: checking missing value and correspnding value using true or false
MissingValues = Data_cleaning.isnull()

# %%
MissingValues
# Out:
#        InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0          False      False        False     False        False      False
# 1          False      False        False     False        False      False
# 2          False      False        False     False        False      False
# 3          False      False        False     False        False      False
# 4          False      False        False     False        False      False
# ...          ...        ...          ...       ...          ...        ...
# 49777      False      False        False     False        False      False
# 49778      False      False        False     False        False      False
# 49779      False      False        False     False        False      False
# 49780      False      False        False     False        False      False
# 49781      False      False        False     False        False      False
#
# ...

# %%
#to access a particular role if it as missing value
Missing_Value = Data_cleaning.isnull().any(axis = 1)

# %%
Missing_Value
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 49777    False
# 49778    False
# 49779    False
# 49780    False
# 49781    False
# Length: 49782, dtype: bool

# %%
#cleaned_data or drop a particular column= crime.drop(columns = category,invoiceno]etc

# %%
cleaned_data = crime.drop(columns = ['YEAR', 'MONTH', 'HOU

# %%
num[0:6]
# Out:
# 0    90
# 1    29
# 2    60
# 3    50
# 4    93
# 5    88
# dtype: int64

# %%
num=pd.Series([90,29,60,50,93,88])
num
# Out:
# 0    90
# 1    29
# 2    60
# 3    50
# 4    93
# 5    88
# dtype: int64

# %%
Data_cleaning[0:10]
# Out:
# 0    "online_retail_dataset.csv"
# dtype: object

# %%
index =['apple','banana','pineapple','pear','orange','cherry']

# %%
#iloc >> location base index
num.iloc[3]
# Out:
# np.float64(93.0)

# %%
num.index=index
num
# Out:
# apple        90
# banana       29
# pineapple    60
# pear         50
# orange       93
# cherry       88
# dtype: int64

# %%
num.name="fruits"
num
# Out:
# apple        90
# banana       29
# pineapple    60
# pear         50
# orange       93
# cherry       88
# Name: fruits, dtype: int64

# %%
num['apple':'pear']
# Out:
# apple        90
# banana       29
# pineapple    60
# pear         50
# Name: fruits, dtype: int64

# %%
vegetable={"avocado":3.4,
                 "kiwi":4.3,
                 "onion":2.0,
                 "ginger":3.3,
                 "galic":5.0,
                 "lemon":6.0
          }

# %%
num=pd.Series(vegetable, name= "vitamins")
num
# Out:
# avocado    3.4
# kiwi       4.3
# onion      2.0
# ginger     3.3
# galic      5.0
# lemon      6.0
# Name: vitamins, dtype: float64

# %%
#condition selection
num>2
# Out:
# avocado     True
# kiwi        True
# onion      False
# ginger      True
# galic       True
# lemon       True
# Name: vitamins, dtype: bool

# %%
num[num>2]
# Out:
# avocado    3.4
# kiwi       4.3
# ginger     3.3
# galic      5.0
# lemon      6.0
# Name: vitamins, dtype: float64

# %%
#logical operation and or not
num[(num<3.0) & (num>=2)]
# Out:
# onion    2.0
# Name: vitamins, dtype: float64

# %%
Data_cleaning.describe
# Out:
# <bound method NDFrame.describe of 0    "online_retail_dataset.csv"
# dtype: object>

# %%
Data_cleaning.unique()
# Out:
# array(['"online_retail_dataset.csv"'], dtype=object)
